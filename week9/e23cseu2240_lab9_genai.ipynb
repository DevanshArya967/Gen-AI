# %%
# ==============================
# COMPONENT I : LSTM SEQUENCE GENERATION
# ==============================

import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# ------------------------------
# Step 1: Dataset
# ------------------------------
text = """
machine learning models learn patterns from data
sequence models process data step by step
recurrent neural networks are designed for sequential tasks
rnn models maintain hidden states across time steps
long short term memory networks solve long dependency problems
lstm uses gates to control information flow
gru models simplify the lstm architecture
sequence prediction is useful in many applications
language modeling predicts the next word in a sentence
speech recognition processes audio sequences
time series forecasting predicts future values
music generation creates new melodies
generative models learn probability distributions
they generate new samples similar to training data
sequence generation is widely used in artificial intelligence
deep learning improves sequence modeling performance
"""

# ------------------------------
# Step 2: Tokenization
# ------------------------------
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])

total_words = len(tokenizer.word_index) + 1

# ------------------------------
# Step 3: Create Input Sequences
# ------------------------------
input_sequences = []

for line in text.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]

    for i in range(1, len(token_list)):
        n_gram_seq = token_list[:i+1]
        input_sequences.append(n_gram_seq)

# ------------------------------
# Step 4: Padding
# ------------------------------
max_seq_len = max([len(x) for x in input_sequences])

input_sequences = pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre')

# ------------------------------
# Step 5: Split into X and y
# ------------------------------
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# ------------------------------
# Step 6: Build LSTM Model
# ------------------------------
model = Sequential()

model.add(Embedding(total_words, 50, input_length=max_seq_len-1))
model.add(LSTM(100))
model.add(Dense(total_words, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')

# ------------------------------
# Step 7: Train Model
# ------------------------------
model.fit(X, y, epochs=300, verbose=1)

# ------------------------------
# Step 8: Generate Text
# ------------------------------
seed_text = "sequence"
next_words = 5

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_seq_len-1, padding='pre')

    predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)[0]

    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break

    seed_text += " " + output_word

print("Generated Text:")
print(seed_text)
# Out:
# Epoch 1/300
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.4672
# Epoch 2/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.4599
# Epoch 3/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.4533
# Epoch 4/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.4459
# Epoch 5/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.4354
# Epoch 6/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.4216
# Epoch 7/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.3988
# Epoch 8/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.3603
# Epoch 9/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3004
# Epoch 10/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.2694
# Epoch 11/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2453
# Epoch 12/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.2089
# Epoch 13/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.1810
# Epoch 14/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.1565
# Epoch 15/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.1340
# Epoch 16/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.0986
# Epoch 17/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.0707
# Epoch 18/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.0358
# Epoch 19/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.0014
# Epoch 20/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.9621
# Epoch 21/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.9200
# Epoch 22/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.8715
# Epoch 23/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.8180
# Epoch 24/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.7688
# Epoch 25/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.7033
# Epoch 26/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.6394
# Epoch 27/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.5841
# Epoch 28/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.5050
# Epoch 29/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.4534
# Epoch 30/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.3787
# Epoch 31/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.3073
# Epoch 32/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.2429
# Epoch 33/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.1902
# Epoch 34/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.1247
# Epoch 35/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.0378
# Epoch 36/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.9835
# Epoch 37/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.9014
# Epoch 38/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.8400
# Epoch 39/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.7681
# Epoch 40/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.7132
# Epoch 41/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.6580
# Epoch 42/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.5828
# Epoch 43/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.5123
# Epoch 44/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.4514
# Epoch 45/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.3901
# Epoch 46/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.3035
# Epoch 47/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.2360
# Epoch 48/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1812
# Epoch 49/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1248
# Epoch 50/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.0733
# Epoch 51/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.0163
# Epoch 52/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9572
# Epoch 53/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9000
# Epoch 54/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8607
# Epoch 55/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8148
# Epoch 56/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.7619
# Epoch 57/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.7223
# Epoch 58/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.6823
# Epoch 59/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.6382
# Epoch 60/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.6019
# Epoch 61/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.5685
# Epoch 62/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5294
# Epoch 63/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5086
# Epoch 64/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.4747
# Epoch 65/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.4276
# Epoch 66/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.4071
# Epoch 67/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.3836
# Epoch 68/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3648
# Epoch 69/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3283
# Epoch 70/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2887
# Epoch 71/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2653
# Epoch 72/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.2398
# Epoch 73/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.2130
# Epoch 74/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1907
# Epoch 75/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1
300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1802
# Epoch 201/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1786
# Epoch 202/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1767
# Epoch 203/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1754
# Epoch 204/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1737
# Epoch 205/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1714
# Epoch 206/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1703
# Epoch 207/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1677
# Epoch 208/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1665
# Epoch 209/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1654
# Epoch 210/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1626
# Epoch 211/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1616
# Epoch 212/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1603
# Epoch 213/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1579
# Epoch 214/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1561
# Epoch 215/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1548
# Epoch 216/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1542
# Epoch 217/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1522
# Epoch 218/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1509
# Epoch 219/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1485
# Epoch 220/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1476
# Epoch 221/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1459
# Epoch 222/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1447
# Epoch 223/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1440
# Epoch 224/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1420
# Epoch 225/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1417
# Epoch 226/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1391
# Epoch 227/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1387
# Epoch 228/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1374
# Epoch 229/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1369
# Epoch 230/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1364
# Epoch 231/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1340
# Epoch 232/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1324
# Epoch 233/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1318
# Epoch 234/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1299
# Epoch 235/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1292
# Epoch 236/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1282
# Epoch 237/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1281
# Epoch 238/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1259
# Epoch 239/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1253
# Epoch 240/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1237
# Epoch 241/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1232
# Epoch 242/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1221
# Epoch 243/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1206
# Epoch 244/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1204
# Epoch 245/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1189
# Epoch 246/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1185
# Epoch 247/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1173
# Epoch 248/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1167
# Epoch 249/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1152
# Epoch 250/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1151
# Epoch 251/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1135
# Epoch 252/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1129
# Epoch 253/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1124
# Epoch 254/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1121
# Epoch 255/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1109
# Epoch 256/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1104
# Epoch 257/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1093
# Epoch 258/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1083
# Epoch 259/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1073
# Epoch 260/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1074
# Epoch 261/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1060
# Epoch 262/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1051
# Epoch 263/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1042
# Epoch 264/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1037
# Epoch 265/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1031
# Epoch 266/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1027
# Epoch 267/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1018
# Epoch 268/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1013
# Epoch 269/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1017
# Epoch 270/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1002
# Epoch 271/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1000
# Epoch 272/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0988
# Epoch 273/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0983
# Epoch 274/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0981
# Epoch 275/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0977
# Epoch 276/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0961
# Epoch 277/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0965
# Epoch 278/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0960
# Epoch 279/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0946
# Epoch 280/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0947
# Epoch 281/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0931
# Epoch 282/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0930
# Epoch 283/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0927
# Epoch 284/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0924
# Epoch 285/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0914
# Epoch 286/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0912
# Epoch 287/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0906
# Epoch 288/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0897
# Epoch 289/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0900
# Epoch 290/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0889
# Epoch 291/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0882
# Epoch 292/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0883
# Epoch 293/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0877
# Epoch 294/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0870
# Epoch 295/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0865
# Epoch 296/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0862
# Epoch 297/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0862
# Epoch 298/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0856
# Epoch 299/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0849
# Epoch 300/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0851
# Generated Text:
# sequence generation is widely used in

# %%
# ==============================
# COMPONENT II : TRANSFORMER SEQUENCE GENERATION
# ==============================

import tensorflow as tf
from tensorflow.keras.layers import Embedding, Dense, LayerNormalization, MultiHeadAttention, Input
from tensorflow.keras.models import Model
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# ------------------------------
# Dataset (copied from Component I for self-containment)
# ------------------------------
text = """
machine learning models learn patterns from data
sequence models process data step by step
recurrent neural networks are designed for sequential tasks
rnn models maintain hidden states across time steps
long short term memory networks solve long dependency problems
lstm uses gates to control information flow
gru models simplify the lstm architecture
sequence prediction is useful in many applications
language modeling predicts the next word in a sentence
speech recognition processes audio sequences
time series forecasting predicts future values
music generation creates new melodies
generative models learn probability distributions
they generate new samples similar to training data
sequence generation is widely used in artificial intelligence
deep learning improves sequence modeling performance
"""

# ------------------------------
# Tokenization (copied from Component I)
# ------------------------------
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])

total_words = len(tokenizer.word_index) + 1

# ------------------------------
# Create Input Sequences (copied from Component I)
# ------------------------------
input_sequences = []

for line in text.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]

    for i in range(1, len(token_list)):
        n_gram_seq = token_list[:i+1]
        input_sequences.append(n_gram_seq)

# ------------------------------
# Padding (copied from Component I)
# ------------------------------
max_seq_len = max([len(x) for x in input_sequences])

input_sequences = pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre')

# ------------------------------
# Split into X and y (copied from Component I)
# ------------------------------
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# ------------------------------
# Positional Encoding
# ------------------------------
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        self.pos_encoding = self.positional_encoding(max_len, d_model)

    def positional_encoding(self, position, d_model):
        angle_rads = self.get_angles(np.arange(position)[:, np.newaxis],
                                     np.arange(d_model)[np.newaxis, :],
                                     d_model)

        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

        return tf.cast(angle_rads[np.newaxis, ...], dtype=tf.float32)

    def get_angles(self, pos, i, d_model):
        angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
        return pos * angle_rates

    def call(self, x):
        return x + self.pos_encoding[:, :tf.shape(x)[1], :]

# ------------------------------
# Transformer Model
# ------------------------------
embed_dim = 64

inputs = Input(shape=(max_seq_len-1,))
x = Embedding(total_words, embed_dim)(inputs)
x = PositionalEncoding(max_seq_len, embed_dim)(x)

attention = MultiHeadAttention(num_heads=2, key_dim=embed_dim)(x, x)
x = LayerNormalization()(attention + x)

x = Dense(64, activation='relu')(x)
x = tf.keras.layers.GlobalAveragePooling1D()(x)

outputs = Dense(total_words, activation='softmax')(x)

transformer_model = Model(inputs, outputs)

transformer_model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')

# ------------------------------
# Train Transformer
# ------------------------------
transformer_model.fit(X, y, epochs=300, verbose=1)

# ------------------------------
# Generate Text
# ------------------------------
seed_text = "learning"

for _ in range(5):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_seq_len-1, padding='pre')

    predicted = np.argmax(transformer_model.predict(token_list, verbose=0), axis=-1)[0]

    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break

    seed_text += " " + output_word

print("Transformer Generated Text:")
print(seed_text)
# Out:
# Epoch 1/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 876ms/step - loss: 4.5845
# Epoch 2/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4712
# Epoch 3/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4245
# Epoch 4/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3998
# Epoch 5/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3826
# Epoch 6/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3667
# Epoch 7/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3521
# Epoch 8/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3433
# Epoch 9/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3310
# Epoch 10/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3176
# Epoch 11/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3049
# Epoch 12/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2933
# Epoch 13/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2856
# Epoch 14/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2713
# Epoch 15/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2615
# Epoch 16/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2534
# Epoch 17/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2391
# Epoch 18/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2286
# Epoch 19/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.2172
# Epoch 20/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2088
# Epoch 21/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.1894
# Epoch 22/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.1775
# Epoch 23/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.1540
# Epoch 24/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.1330
# Epoch 25/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1100
# Epoch 26/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.0722
# Epoch 27/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0312
# Epoch 28/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.9953
# Epoch 29/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.9423
# Epoch 30/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8829
# Epoch 31/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8280
# Epoch 32/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7580
# Epoch 33/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6858
# Epoch 34/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6198
# Epoch 35/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.5437
# Epoch 36/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4611
# Epoch 37/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.3873
# Epoch 38/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.2845
# Epoch 39/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2036
# Epoch 40/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1049
# Epoch 41/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0150
# Epoch 42/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9135
# Epoch 43/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8249
# Epoch 44/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7272
# Epoch 45/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6138
# Epoch 46/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5253
# Epoch 47/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4121
# Epoch 48/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3075
# Epoch 49/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2013
# Epoch 50/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1081
# Epoch 51/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0002
# Epoch 52/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.